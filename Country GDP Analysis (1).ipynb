# %% [markdown]
# # Country GDP Analysis using pandas and
#    - pandas library use to work with the data frame or in data-set

# %%
import pandas as pd # import pandas library

# %%
# read the file from the system
df =pd.read_csv(r'C:\Users\sunil\Desktop\Data Science and AI NIT\22nd - workshop gdp analysis\22nd\DataFrame_ Pandas\data.csv')

# %%
df # print the data \frame
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
len(df) # check the length of the data frame
# Out:
# 195

# %%
df.shape # shape() function gives the rows and columns of data frame
# Out:
# (195, 5)

# %%
df.columns # columns attribute give the all columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
type(df) # check what is the type of the data frame
# Out:
# pandas.core.frame.DataFrame

# %%
pd.isnull(df) # cheching whether any null value present in the data set or not
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.info() # info() function gives the data set information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
pd.isna(df) # isna() is also use to check wheather there is any null value present in the data set
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
pd.isnull(df).sum()# isnull().sum() gives all the null value details and how many null value present in any attribute
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.head() # it gives us top 5 data from the data set
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.tail() # it gives last 5 data from the data set
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.head(3) # inside head() function if we asign value like 2 or 3 it gives top 2 or 3 data value respectively
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244           78.9          High income
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income

# %%
len(df.columns) # to get how many column are present in form of number apply length function
# Out:
# 5

# %%
df.tail(2) # it gives last 2 datafrom data set
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 193      Zambia         ZMB     40.471           15.4  Lower middle income
# 194    Zimbabwe         ZWE     35.715           18.5           Low income

# %%
df[:] # slicing on the data set its same as the list slicing
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[::-1] # to print reverse order the data frame
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
df[2:70] # 2 is the starting data row and (70-1) last data row to print
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  \
# 2                 Angola         AGO     45.985        19.1000
# 3                Albania         ALB     12.877        57.2000
# 4   United Arab Emirates         ARE     11.044        88.0000
# 5              Argentina         ARG     17.716        59.9000
# 6                Armenia         ARM     13.308        41.9000
# ..                   ...         ...        ...            ...
# 65           Gambia, The         GMB     42.525        14.0000
# 66         Guinea-Bissau         GNB     37.503         3.1000
# 67     Equatorial Guinea         GNQ     35.362        16.4000
# 68                Greece         GRC      8.500        59.8663
# 69               Grenada         GRD     19.334        35.0000
#
#             IncomeGroup
# 2   Upper middle income
# 3   Upper middle income
# 4           High income
# 5           High income
# 6   Lower middle income
# ..                  ...
# 65           Low income
# ...

# %%
df[1:50:10]  # 1 is starting data (50-1) last data andstep count is 10
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 1   Afghanistan         AFG     35.253           5.90           Low income
# 11      Burundi         BDI     44.151           1.30           Low income
# 21       Belize         BLZ     23.092          33.60  Upper middle income
# 31  Switzerland         CHE     10.200          86.34          High income
# 41         Cuba         CUB     10.400          27.93  Upper middle income

# %%
df.describe() # descriptive statistics on  numerical data describe() work on only numerical data give a description
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df.describe().transpose() # the descriptiion table to transpose
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.columns=['Country','Code','BirthR','usernet','groupincm']  # change the data frame attribute into another name

# %%
df.head()
# Out:
#                 Country Code  BirthR  usernet            groupincm
# 0                 Aruba  ABW  10.244     78.9          High income
# 1           Afghanistan  AFG  35.253      5.9           Low income
# 2                Angola  AGO  45.985     19.1  Upper middle income
# 3               Albania  ALB  12.877     57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044     88.0          High income

# %%
df.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup'] # change the data frame as it previous

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df[0:5] # data frame slicing from 0 to 4 th data
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df_category= df[['CountryName',	'CountryCode','IncomeGroup']] # retrive the attribute and data of countryname, countrycode,and birthRate
df_category
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df_numeric=df[['BirthRate','InternetUsers']]

# %%
df_numeric
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
df[['CountryName','BirthRate']]
# Out:
#               CountryName  BirthRate
# 0                   Aruba     10.244
# 1             Afghanistan     35.253
# 2                  Angola     45.985
# 3                 Albania     12.877
# 4    United Arab Emirates     11.044
# ..                    ...        ...
# 190           Yemen, Rep.     32.947
# 191          South Africa     20.850
# 192      Congo, Dem. Rep.     42.394
# 193                Zambia     40.471
# 194              Zimbabwe     35.715
#
# [195 rows x 2 columns]

# %%
#combine tow attribute and apply slicing on it
df[['CountryName','InternetUsers']][5:20]
# Out:
#                CountryName  InternetUsers
# 5                Argentina       59.90000
# 6                  Armenia       41.90000
# 7      Antigua and Barbuda       63.40000
# 8                Australia       83.00000
# 9                  Austria       80.61880
# 10              Azerbaijan       58.70000
# 11                 Burundi        1.30000
# 12                 Belgium       82.17020
# 13                   Benin        4.90000
# 14            Burkina Faso        9.10000
# 15              Bangladesh        6.63000
# 16                Bulgaria       53.06150
# 17                 Bahrain       90.00004
# 18            Bahamas, The       72.00000
# 19  Bosnia and Herzegovina       57.79000

# %%
# we can right also this type
df[2:10][['CountryName','BirthRate']]
# Out:
#             CountryName  BirthRate
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447
# 8             Australia     13.200
# 9               Austria      9.400

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df[['CountryCode','BirthRate','InternetUsers']][2:15]
# Out:
#    CountryCode  BirthRate  InternetUsers
# 2          AGO     45.985        19.1000
# 3          ALB     12.877        57.2000
# 4          ARE     11.044        88.0000
# 5          ARG     17.716        59.9000
# 6          ARM     13.308        41.9000
# 7          ATG     16.447        63.4000
# 8          AUS     13.200        83.0000
# 9          AUT      9.400        80.6188
# 10         AZE     18.300        58.7000
# 11         BDI     44.151         1.3000
# 12         BEL     11.200        82.1702
# 13         BEN     36.440         4.9000
# 14         BFA     40.551         9.1000

# %%
# math matical operation (multiply birthrate * internetusers)
New=df.BirthRate*df.InternetUsers
New
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
# Adding new columns in data frame
df['New']=df.BirthRate*df.InternetUsers

# %%
df # a New column added succesfully
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup       New
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# ...

# %%
# to delet the columns
df=df.drop("New",axis=1) # remove the column from data frame

# %%
# chek comparison on data frame
df.InternetUsers < 5 # it check if condition satisfy then its return true
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
filter=df.BirthRate < 20
filter
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
# to get the actual value with the date
df[filter] # it show the data of where BirthRate less then 20
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244           78.9
# 3                           Albania         ALB     12.877           57.2
# 4              United Arab Emirates         ARE     11.044           88.0
# 5                         Argentina         ARG     17.716           59.9
# 6                           Armenia         ARM     13.308           41.9
# ..                              ...         ...        ...            ...
# 181                   United States         USA     12.500           84.2
# 183  St. Vincent and the Grenadines         VCT     16.306           52.0
# 184                   Venezuela, RB         VEN     19.842           54.9
# 185           Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                         Vietnam         VNM     15.537           43.9
#
#              IncomeGroup
# 0            High income
# 3    Upper middle income
# ...

# %%
filter2=df.InternetUsers< 10
filter2
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[filter2] # to get the data where the internet user less to 10 value
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 15                 Bangladesh         BGD     20.142           6.63
# 29   Central African Republic         CAF     34.076           3.50
# 34              Cote d'Ivoire         CIV     37.320           8.40
# 35                   Cameroon         CMR     37.236           6.40
# 36                Congo, Rep.         COG     37.011           6.60
# 38                    Comoros         COM     34.326           6.50
# 46                   Djibouti         DJI     25.486           9.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# ...

# %%
#after filter out the we check where the both condition are true birtrate and internetuser
df[filter & filter2] # it work for logical and operator
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 117     Myanmar         MMR     18.119            1.6  Lower middle income

# %%
# check in the data set where is lower middle income
df[df.IncomeGroup=="Lower middle income"] # it givethe data where the income group is lower middle income
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 6                  Armenia         ARM     13.308        41.9000
# 15              Bangladesh         BGD     20.142         6.6300
# 23                 Bolivia         BOL     24.236        36.9400
# 27                  Bhutan         BTN     18.134        29.9000
# 34           Cote d'Ivoire         CIV     37.320         8.4000
# 35                Cameroon         CMR     37.236         6.4000
# 36             Congo, Rep.         COG     37.011         6.6000
# 39              Cabo Verde         CPV     21.625        37.5000
# 46                Djibouti         DJI     25.486         9.5000
# 51        Egypt, Arab Rep.         EGY     28.032        29.4000
# 59   Micronesia, Fed. Sts.         FSM     23.511        27.8000
# 62                 Georgia         GEO     13.332        43.3000
# 63                   Ghana         GHA     33.131        12.3000
# ...

# %%
# to check how many uniqe value in a atribute
df.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
# to calculate how much uniq value a data set have for an attribute
df.IncomeGroup.nunique()
# Out:
# 4

# %% [markdown]
# ## from here use of seaborn

# %%
import matplotlib.pyplot as plt # import of matplotlib for graph or visualization

# %%
import seaborn as sns # import seaborn for statistical visualization

# %%
# %matplotlib inline # to get the graph is the size of the screen
plt.rcParams['figure.figsize']=6,5 # define the graph size
# for remove all waring messeges we have to import this
import warnings
warnings.filterwarnings('ignore')
# Out:
# UsageError: unrecognized arguments: # to get the graph is the size of the screen

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
# lets do UNIVERIENT ANALYSIS
vis1= sns.distplot(df['InternetUsers']) # plot distribution graph based on internet user
# Out:
# C:\Users\sunil\AppData\Local\Temp\ipykernel_18788\3402233111.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis1= sns.distplot(df['InternetUsers']) # plot distribution graph based on internet user

# %%
vis2= sns.displot(df['BirthRate'],bins=10) # no need to draw the distribution line , bin referce who many boxes created on graph

# %%
# plot box diagram
vis3= sns.boxplot(data=df, x= 'IncomeGroup',y='BirthRate') # taking BI-VARIENT data

# %%
vis5 = sns.lmplot(data=df, x= 'InternetUsers',y='BirthRate',fit_reg=True) # to get linear model , for get regression line use fit_reg

# %%
vis4=sns.lmplot(data=df, x= 'InternetUsers',y='BirthRate',fit_reg=False) # lmplot to plot the linear model graph, if you dont want regressioon line

# %%
vis6= sns.lmplot(data= df, x= 'InternetUsers', y= 'BirthRate',fit_reg=True,hue='IncomeGroup') # it give based on income group
# we work on legent on panda but in seaborn we work in hue

# %%
vis6= sns.lmplot(data= df, x= 'InternetUsers', y= 'BirthRate',fit_reg=True,hue='IncomeGroup',height=8) # height key used to enlargee for better understand

# %% [markdown]
# ## country GDP analysis completed

# %% [markdown]
# ### In thesection we learn
#    - importing the data frame
#    - data frame via pandas
#    - exploring the data frame head(),tail(),info(), decsribe()
#    - rename columns
#    - subseting the data frame
#    - basic operation with the data frame
#    - filtering on the data frame
#    - introdusing the seaborn --> .distplot | .displot | .lmplot(fit_reg) | outlier | hue parameter(same as the legend)
#    - univeriant(analysis unsing one atribute), biveriante(using two atribute), multivarient(using more than two atribute)
